# %% [markdown]
# #Project Milestone 3

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# *Reading the csv file

# %%
student= pd.read_csv('student.csv')
student
# Out:
#      Unnamed: 0    Id  Student_Age     Sex High_School_Type Scholarship  \
# 0             0  5001           21    Male            Other         50%
# 1             1  5002           20    Male            Other         50%
# 2             2  5003           21    Male            State         50%
# 3             3  5004           18  Female          Private         50%
# 4             4  5005           22    Male          Private         50%
# ..          ...   ...          ...     ...              ...         ...
# 140         140  5141           22  Female            State         50%
# 141         141  5142           18  Female            State         75%
# 142         142  5143           18  Female          Private         75%
# 143         143  5144           22  Female            State         75%
# 144         144  5145           18  Female          Private        100%
#
#     Additional_Work Sports_activity Transportation  Weekly_Study_Hours  \
# ...

# %% [markdown]
# Milestone #3 Update: Based on some feedback from my peers in class, they thought it might be a good idea to include Sports and Work as extracirriculars in my dataset and see how affects student habits and final grades. Cleaning up the Data and narrowing do the columns into the student habits/ behaviors. These will be the columns I use to create my visualizations.

# %%
selected_columns = ['Weekly_Study_Hours', 'Attendance', 'Reading', 'Notes', 'Listening_in_Class', 'Grade', 'Sports_activity','Additional_Work']

stu_narrowed = student[selected_columns]
stu_narrowed
# Out:
#      Weekly_Study_Hours Attendance Reading Notes Listening_in_Class Grade  \
# 0                     0     Always     Yes   Yes                 No    AA
# 1                     0     Always     Yes    No                Yes    AA
# 2                     2      Never      No    No                 No    AA
# 3                     2     Always      No   Yes                 No    AA
# 4                    12     Always     Yes    No                Yes    AA
# ..                  ...        ...     ...   ...                ...   ...
# 140                   0     Always      No   Yes                 No    CC
# 141                   0      Never      No   Yes                Yes    CC
# 142                   0     Always     Yes    No                 No    AA
# 143                  12  Sometimes      No   Yes                 No    CB
# 144                  12     Always     Yes    No                Yes    BB
#
#     Sports_activity Additional_Work
# 0                No             Yes
# ...

# %% [markdown]
# #Milestone #3 Update: Based on feedback, I am moving forward with converting the double letter grades into broader categories. This will helpt to create a more readible figure.
#
# #removing rows with 6 as the 'notes' and 'Listening_in_Class'
#
# #removing the row with 3 as the value for 'Attendance'

# %%
new_grade = {
    'AA': 'Excellent',
    'BA': 'Good',
    'BB': 'Good',
    'CB': 'Average',
    'CC': 'Average',
    'DC': 'Below Average',
    'DD': 'Below Average',
    'Fail': 'Fail'
}


stu_clean = stu_narrowed[stu_narrowed['Notes'] != '6']
stu_clean = stu_clean[stu_clean['Listening_in_Class'] != '6']
stu_clean = stu_clean[stu_clean['Attendance'] != '3']

stu_clean['Grade'] = stu_clean['Grade'].map(new_grade)

print(stu_clean)
# Out:
#      Weekly_Study_Hours Attendance Reading Notes Listening_in_Class  \
# 0                     0     Always     Yes   Yes                 No
# 1                     0     Always     Yes    No                Yes
# 2                     2      Never      No    No                 No
# 3                     2     Always      No   Yes                 No
# 4                    12     Always     Yes    No                Yes
# ..                  ...        ...     ...   ...                ...
# 140                   0     Always      No   Yes                 No
# 141                   0      Never      No   Yes                Yes
# 142                   0     Always     Yes    No                 No
# 143                  12  Sometimes      No   Yes                 No
# 144                  12     Always     Yes    No                Yes
#
#          Grade Sports_activity Additional_Work
# 0    Excellent              No             Yes
# 1    Excellent              No             Yes
# ...

# %% [markdown]
# *When it comes to creating a visualization for this project, I want to make a visualization that is easily readable by my audiences, which are high school students and as well as other staff in my department. Since my data is mostly categorical, I will use categorical visualizations.

# %% [markdown]
# FIGURE 3
#
# Pros:
# -Relationship between notetaking and grades can easily be intepreted
#
# Cons:
#
# -Lacks detail and variation across other categories

# %%
#Figure displaying grade distribution regarding attendance and updating grade order

# %%
grade_order = ['Excellent', 'Good', 'Average', 'Below Average', 'Fail']
fig1 = sns.countplot(data=stu_clean, x="Grade", hue="Attendance", order=grade_order)

# Set the labels
plt.xlabel('Grade')
plt.ylabel('Number of Students')

# Show the plot
plt.show()

# %%
#Figure displaying grade distribution regarding listening in class

# %%
fig2 = sns.countplot(data=stu_clean, x="Grade", hue="Notes", order=grade_order)


plt.xlabel('Grade')
plt.ylabel('Number of Students')


plt.show()

# %%
#Figure is displaying grade distribution regarding listening in class

# %%
fig3 = sns.countplot(data=stu_clean, x="Grade", hue="Listening_in_Class", order=grade_order)


plt.xlabel('Grade')
plt.ylabel('Number of Students')


plt.show()

# %%
fig4 = sns.countplot(data=stu_clean, x="Grade", hue="Reading", order=grade_order)


plt.xlabel('Grade')
plt.ylabel('Number of Students')


plt.show()

# %% [markdown]
# Takeaways and Next Steps:
#
# I'm a bit behind where I aimed to be for Milestone #3 due to some last-minute changes I've made to the figure I intend to use. Still, I'm confident that these countplots are highly readable, and my audience shouldn't have any trouble interpreting them. I've broken down the distribution of grades based on each student habit: notes, reading, listening in class, and attendance. I'm still undecided whether to keep the graphs separate or find a way to combine them into a unified display.
#
# Moreover, I'm exploring how to incorporate the extracurricular categories, work and sports, into my figures. As part of this milestone, I've converted the grades into categories: Excellent, Good, Average, Below Average, and Fail. Additionally, I've updated the grade order displayed on the graphs.
